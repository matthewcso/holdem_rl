# %%
''' An example of solve Leduc Hold'em with CFR
'''
import tensorflow as tf
import numpy as np

import rlcard
from rlcard.agents import DeepCFR #CFRAgent
from rlcard.agents import RandomAgent
from rlcard import models
from rlcard.utils import set_global_seed, tournament
from rlcard.utils import Logger

# Make environment and enable human mode
env = rlcard.make('no-limit-holdem', config={'seed': 0, 'allow_step_back':True})
eval_env = rlcard.make('no-limit-holdem', config={'seed': 0})

# Set the iterations numbers and how frequently we evaluate the performance and save model
evaluate_every = 100
save_plot_every = 1000
evaluate_num = 100
episode_num = 10000

# The paths for saving the logs and learning curves
log_dir = './experiments/leduc_holdem_cfr_result/'
sess=tf.Session()
# Set a global seed
set_global_seed(0)

# Initilize CFR Agent
agent = DeepCFR(sess,env,num_step=5, num_traversals=1)
random_agent = RandomAgent(action_num=eval_env.action_num)

# Evaluate CFR against pre-trained NFSP
eval_env.set_agents([agent, random_agent])

# Init a Logger to plot the learning curve
logger = Logger(log_dir)

for episode in range(episode_num):
    agent.train()
    print('\rIteration {}'.format(episode), end='')
    # Evaluate the performance. Play with NFSP agents.
    if episode % evaluate_every == 0:
     #   saver = tf.train.Saver()
     #   save_dir = log_dir
     #  saver.save(sess, os.path.join(save_dir, 'model'))
        logger.log_performance(env.timestep, tournament(eval_env, evaluate_num)[0])

# Close files in the logger
logger.close_files()

# Plot the learning curve
logger.plot('CFR')
# Out:
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From c:\Users\somat\Documents\GitHub\RL\rlcard\utils\utils.py:332: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1866: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py:153: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From C:\Users\somat\Anaconda3\envs\tensorflow-env\lib\site-packages\tensorflow_core\python\ops\losses\losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py:156: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py:164: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py:189: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7a5989ba721d> in <module>
#      38
#      39 for episode in range(episode_num):
# ---> 40     agent.train()
#      41     print('\rIteration {}'.format(episode), end='')
#      42     # Evaluate the performance. Play with NFSP agents.
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in train(self)
#     204                 init_state, init_player = self._env.reset()
#     205                 self._root_node = init_state
# --> 206             for _ in range(self._num_traversals):
#     207                 self._traverse_game_tree(self._root_node, init_player)
#     208             print('Training: ')
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
# --> 320                 self.traverse.append((action, state, child_state))
#     321                 expected_payoff[action] = self._traverse_game_tree(child_state, player)
#     322             for _ in range(self._env.player_num):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     342                 StrategyMemory(
#     343                     state['obs'].flatten(),
# --> 344                     self._iteration, strategy))
#     345             return self._traverse_game_tree(child_state, player)
#     346
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\agents\deep_cfr_agent.py in _traverse_game_tree(self, state, player, count)
#     316             # Update the policy over the info set & actions via regret matching.
#     317             _, strategy = self._sample_action_from_advantage(state, player)
# --> 318             for action in actions:
#     319                 child_state, _ = self._env.step(action)
#     320                 self.traverse.append((action, state, child_state))
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\envs\env.py in step(self, action, raw_action)
#      96         next_state, player_id = self.game.step(action)
#      97
# ---> 98         return self._extract_state(next_state), player_id
#      99
#     100     def step_back(self):
#
# c:\Users\somat\Documents\GitHub\RL\rlcard\envs\nolimitholdem.py in _extract_state(self, state)
#      73         pot = state['pot']
#      74         EHS_preflop = unified_EHS(to_deuces_intlist(state['hand']), [], en, hs_model, ehs_model, lookup_table)
# ---> 75         EHS_postflop = unified_EHS(to_deuces_intlist(state['hand']), to_deuces_intlist(state['public_cards']), en, hs_model, ehs_model, lookup_table)
#      76         past_aggression = state['past_aggression']
#      77         street_aggression=state['street_aggression']
#
# c:\Users\somat\Documents\GitHub\RL\fast_utils\unified_EHS.py in unified_EHS(hole_cards, board, en, HS_model, EHS_model, lookup)
#      10         return read_lookup_table(hole_cards, lookup)[0]
#      11     elif len(board) == 5:
# ---> 12         return nn_HS(hole_cards, board, en, HS_model)
#      13     else:
#      14         return nn_EHS(hole_cards, board, en, HS_model, EHS_model)
#
# c:\Users\somat\Documents\GitHub\RL\fast_utils\hand_strength\nn_HS.py in nn_HS(hole_cards, board, en, model)
#      35 def nn_HS(hole_cards, board, en, model):
#      36     features = np.asarray([encode_hs(hole_cards, board, en)])
# ---> 37     this_HS = model.predict(features)
#      38
#      39     return this_HS[0][0]
#
# ~\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\envs\tensorflow-env\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\envs\tensorflow-env\lib\site-packages\tensorflow_core\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
